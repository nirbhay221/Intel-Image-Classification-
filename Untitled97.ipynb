# %%
import tensorflow as tf
import csv
import matplotlib.pyplot as plt
import os
import numpy as np 
import zipfile as zipfile

# %%
zip_ref = zipfile.ZipFile('/content/archive (29).zip','r')
zip_ref.extractall('/tmp/')
zip_ref.close()
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-10-cd2ee26119bf> in <module>()
# ----> 1 zip_ref = zipfile.ZipFile('/content/archive (29).zip','r')
#       2 zip_ref.extractall('/tmp/')
#       3 zip_ref.close()
#
# /usr/lib/python3.6/zipfile.py in __init__(self, file, mode, compression, allowZip64)
#    1129         try:
#    1130             if mode == 'r':
# -> 1131                 self._RealGetContents()
#    1132             elif mode in ('w', 'x'):
#    1133                 # set the modified flag so central directory gets written
#
# /usr/lib/python3.6/zipfile.py in _RealGetContents(self)
#    1196             raise BadZipFile("File is not a zip file")
#    1197         if not endrec:
# -> 1198             raise BadZipFile("File is not a zip file")
#    1199         if self.debug > 1:
#    1200             print(endrec)
#
# ...

# %%
local_dir = '/tmp/archive (29)/'
train_dir = os.path.join(local_dir,'seg_train/seg_train/') 
test_dir = os.path.join(local_dir,'seg_test/seg_test/')

# %%
train_buildings_dir = os.path.join(train_dir,'buildings')
train_forest_dir= os.path.join(train_dir,'forest')
train_glacier_dir = os.path.join(train_dir,'glacier')
train_mountain_dir= os.path.join(train_dir,'mountain')
train_sea_dir= os.path.join(train_dir,'sea')
train_street_dir= os.path.join(train_dir,'street')
train_buildings_dir
# Out:
# '/tmp/archive (29)/seg_train/seg_train/buildings'

# %%
test_buildings_dir = os.path.join(test_dir,'buildings')
test_forest_dir= os.path.join(test_dir,'forest')
test_glacier_dir = os.path.join(test_dir,'glacier')
test_mountain_dir= os.path.join(test_dir,'mountain')
test_sea_dir= os.path.join(test_dir,'sea')
test_street_dir= os.path.join(test_dir,'street')

# %%
building_files = os.listdir(train_buildings_dir)
forest_files= os.listdir(train_forest_dir)
glacier_files= os.listdir(train_glacier_dir)
mountain_files= os.listdir(train_mountain_dir)
sea_files =os.listdir(train_sea_dir)
street_files= os.listdir(train_street_dir)
len(building_files)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-26402eed7a51> in <module>()
# ----> 1 building_files = os.listdir(train_buildings_dir)
#       2 forest_files= os.listdir(train_forest_dir)
#       3 glacier_files= os.listdir(train_glacier_dir)
#       4 mountain_files= os.listdir(train_mountain_dir)
#       5 sea_files =os.listdir(train_sea_dir)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/archive (29)/seg_train/seg_train/buildings'

# %%
pic_index=2
next_buildings  = [os.path.join(train_buildings_dir,fname) for fname in building_files[pic_index-2:pic_index]]
next_forest =[os.path.join(train_forest_dir,fname) for fname in forest_files[pic_index-2:pic_index]]
next_glacier= [os.path.join(train_glacier_dir,fname) for fname in glacier_files[pic_index-2:pic_index]]
next_mountain =[os.path.join(train_mountain_dir,fname) for fname in mountain_files[pic_index-2:pic_index]]
next_sea= [os.path.join(train_sea_dir,fname) for fname in sea_files[pic_index-2:pic_index]]
next_street= [os.path.join(train_street_dir,fname) for fname in street_files[pic_index-2:pic_index]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-446fa070c44a> in <module>()
#       1 pic_index=2
# ----> 2 next_buildings  = [os.path.join(train_buildings_dir,fname) for fname in building_files[pic_index-2:pic_index]]
#       3 next_forest =[os.path.join(train_forest_dir,fname) for fname in forest_files[pic_index-2:pic_index]]
#       4 next_glacier= [os.path.join(train_glacier_dir,fname) for fname in glacier_files[pic_index-2:pic_index]]
#       5 next_mountain =[os.path.join(train_mountain_dir,fname) for fname in mountain_files[pic_index-2:pic_index]]
#
# NameError: name 'building_files' is not defined

# %%
import matplotlib.image as mpimg
for i,img_path in enumerate(next_buildings+next_forest+next_glacier+next_mountain+next_sea+next_street):
  img = mpimg.imread(img_path)
  plt.imshow(img)
  plt.axis('Off')
  plt.show()

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255.,rotation_range=40,zoom_range=0.2,width_shift_range=0.2,height_shift_range=0.2,shear_range=0.2,fill_mode='nearest',horizontal_flip=True)

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255.)

# %%
train_data_generator = train_datagen.flow_from_directory(train_dir,class_mode='categorical',batch_size=32,target_size=(150,150))
test_data_generator = test_datagen.flow_from_directory(test_dir,class_mode='categorical',batch_size=32,target_size=(150,150))
# Out:
# Found 6428 images belonging to 6 classes.
# Found 641 images belonging to 6 classes.

# %%
model = tf.keras.models.Sequential([
                                    tf.keras.layers.Conv2D(256,(3,3),activation ='relu',input_shape=(150,150,3)),
                                    tf.keras.layers.MaxPooling2D((2,2)),
                                    tf.keras.layers.Conv2D(256,(3,3),activation ='relu',input_shape=(150,150,3)),
                                    tf.keras.layers.MaxPooling2D((2,2)),
                                    tf.keras.layers.Conv2D(512,(3,3),activation ='relu',input_shape=(150,150,3)),
                                    tf.keras.layers.MaxPooling2D((2,2)),
                                    tf.keras.layers.Conv2D(512,(3,3),activation ='relu',input_shape=(150,150,3)),
                                    tf.keras.layers.MaxPooling2D((2,2)),
                                    tf.keras.layers.Conv2D(1024,(3,3),activation ='relu',input_shape=(150,150,3)),
                                    tf.keras.layers.MaxPooling2D((2,2)),
                                    tf.keras.layers.Flatten(),
                                    tf.keras.layers.Dropout(0.9),
                                    tf.keras.layers.Dense(512,activation='relu'),
                                    tf.keras.layers.Dense(6,activation='relu')
                                    
])

# %%
model.compile(loss='categorical_crossentropy',optimizer='rmsprop',metrics=['accuracy'])
history=model.fit(train_data_generator,validation_data=test_data_generator,epochs=10)
# Out:
# Epoch 1/10
# 201/201 [==============================] - 431s 2s/step - loss: 6.5570 - accuracy: 0.2968 - val_loss: 6.2405 - val_accuracy: 0.4789
# Epoch 2/10
# 201/201 [==============================] - 424s 2s/step - loss: 6.7163 - accuracy: 0.3656 - val_loss: 4.5155 - val_accuracy: 0.5585
# Epoch 3/10
# 201/201 [==============================] - 422s 2s/step - loss: 6.4855 - accuracy: 0.3813 - val_loss: 4.7113 - val_accuracy: 0.4899
# Epoch 4/10
# 201/201 [==============================] - 424s 2s/step - loss: 6.3213 - accuracy: 0.3867 - val_loss: 4.4898 - val_accuracy: 0.5335
# Epoch 5/10
# 201/201 [==============================] - 425s 2s/step - loss: 7.0720 - accuracy: 0.3692 - val_loss: 4.4391 - val_accuracy: 0.5523
# Epoch 6/10
# 201/201 [==============================] - 428s 2s/step - loss: 6.3210 - accuracy: 0.3891 - val_loss: 4.4603 - val_accuracy: 0.5351
# Epoch 7/10
# 201/201 [==============================] - ETA: 0s - loss: 6.2707 - accuracy: 0.3942
